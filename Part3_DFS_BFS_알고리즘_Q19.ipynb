# %% [markdown]
# <a href="https://colab.research.google.com/github/Steve-YJ/21_kaggle_master/blob/main/Part3_DFS_BFS_%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98_Q19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 3. 알고리즘 유형별 기출문제
# > 본 노트북은 나동빈 저자의 '이것이 취업을 위한 코딩테스트' 문제를 풀이한 노트북입니다

# %% [markdown]
# # Q19. 연산자 끼워 넣기
# * 난이도 2
# * 풀이시간 30분
# * 기출: 삼성전자 SW 역량테스트

# %%
N = int(input())
nums = list(map(int, input().split()))
add, sub, mul, div = map(int, input().split())

min_, max_ = 1e9, -1e9

def dfs(i, res, add, sub, mul, div):
    global max_, min_
    if i == N:
        max_ = max(res, max_)
        min_ = min(res, min_)
        return
    
    else:
        if add:
            dfs(i+1, res+nums[i], add-1, sub, mul, div)
        if sub:
            dfs(i+1, res-nums[i], add, sub-1, mul, div)
        if mul:
            dfs(i+1, res*nums[i], add, sub, mul-1, div)
        if div:
            dfs(i+1, int(res/nums[i]), add, sub, mul, div-1)

dfs(1, nums[0], add, sub, mul, div)

print(max_)
print(min_)
# Out:
# 2
# 5 6
# 0 0 1 0
# 30
# 30

# %% [markdown]
# 어렵네예...

# %% [markdown]
# ## Next
# * 3월 한 달동안 시뮬레이션, DFS/BFS 몇 번 돌리자...
# * 확실히 내것으로 가져가자! Can do it! -21.03.01.mon-
